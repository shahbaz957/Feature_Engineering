# %%
# Re-import necessary libraries after code execution environment reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Simulate a simple 2D dataset with correlation
np.random.seed(42)
n_samples = 100
x1 = np.random.normal(0, 1, n_samples)
x2 = 2 * x1 + np.random.normal(0, 1, n_samples)
X = np.column_stack((x1, x2))

# Convert to DataFrame
df = pd.DataFrame(X, columns=['Feature_1', 'Feature_2'])

# Step 1: Standardize the dataset
scaler = StandardScaler(with_std = False)
X_scaled = scaler.fit_transform(df)

# Step 2: Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Explained variance and components
explained_variance = pca.explained_variance_ratio_
components = pca.components_

# Plot original data and principal components
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(X_scaled[:, 0], X_scaled[:, 1], alpha=0.6, label='Original Data')
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    ax.plot([0, v[0]], [0, v[1]], linewidth=3, label=f'PC', color='r')

ax.set_xlabel("Standardized Feature 1")
ax.set_ylabel("Standardized Feature 2")
ax.set_title("PCA on 2D Dataset")
ax.legend()
ax.grid(True)
plt.axis('equal')
plt.show()

# %%
X_scaled.mean()
# Out:
# 1.7763568394002505e-17

# %%
cov_mat = np.cov(df)

# %%
from numpy import linalg

# %%
linalg.eigvals(cov_mat)[45]
# Out:
# (1.1400581203059009e-16+1.7550158525141888e-17j)

# %%
import sklearn as sk
